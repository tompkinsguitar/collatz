# %%
from collatz import Collatz

# %%
n = 987654321*987654321
c = Collatz(n=n, count_limit=1e100)

# %%
c.compute()

# %%
c.count
# Out:
# 322

# %%
c.valid
# Out:
# True

# %%
c.final_number
# Out:
# 1

# %%
c.sequence
# Out:
# [975461057789971041,
#  2926383173369913124,
#  1463191586684956562,
#  731595793342478281,
#  2194787380027434844,
#  1097393690013717422,
#  548696845006858711,
#  1646090535020576134,
#  823045267510288067,
#  2469135802530864202,
#  1234567901265432101,
#  3703703703796296304,
#  1851851851898148152,
#  925925925949074076,
#  462962962974537038,
#  231481481487268519,
#  694444444461805558,
#  347222222230902779,
#  1041666666692708338,
#  520833333346354169,
#  1562500000039062508,
#  781250000019531254,
#  390625000009765627,
#  1171875000029296882,
#  585937500014648441,
#  1757812500043945324,
#  878906250021972662,
#  439453125010986331,
#  1318359375032958994,
#  659179687516479497,
#  1977539062549438492,
#  988769531274719246,
#  494384765637359623,
#  1483154296912078870,
#  741577148456039435,
#  2224731445368118306,
#  1112365722684059153,
#  3337097168052177460,
#  1668548584026088730,
#  834274292013044365,
#  2502822876039133096,
#  1251411438019566548,
# ...
